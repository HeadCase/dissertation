# %%
import maup
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
districts = gpd.read_file("https://www2.census.gov/geo/tiger/TIGER2012/SLDU/tl_2012_25_sldu.zip")

# %%
districts.head(10)
# Out:
#   STATEFP SLDUST  GEOID                              NAMELSAD LSAD   LSY  \
# 0      25    023  25023               Cape & Islands District   07  2010
# 1      25    ZZZ  25ZZZ    State Senate Districts not defined   00  2010
# 2      25    049  25049    Second Plymouth & Bristol District   07  2010
# 3      25    045  25045           Norfolk & Plymouth District   07  2010
# 4      25    050  25050           Plymouth & Norfolk District   07  2010
# 5      25    022  25022    Second Bristol & Plymouth District   07  2010
# 6      25    021  25021     First Bristol & Plymouth District   07  2010
# 7      25    048  25048     First Plymouth & Bristol District   07  2010
# 8      25    044  25044  Norfolk, Bristol & Plymouth District   07  2010
# 9      25    047  25047        Plymouth & Barnstable District   07  2010
#
#    MTFCC FUNCSTAT       ALAND      AWATER     INTPTLAT      INTPTLON  \
# 0  G5210        N  1014405476    62391759  +41.7664703  -070.0566010
# ...

# %%
units = gpd.read_file("zip://./BG25.zip")
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsizip/./BG25.zip' does not exist in the file system, and is not recognized as a supported dataset name.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-8-b2522a1f6673> in <module>
# ----> 1 units = gpd.read_file("zip://./BG25.zip")
#
# ~/opt/anaconda3/envs/gerry/lib/python3.8/site-packages/geopandas/io/file.py in read_file(filename, bbox, mask, rows, **kwargs)
#      87
#      88     with fiona_env():
# ---> 89         with reader(path_or_bytes, **kwargs) as features:
#      90
#      91             # In a future Fiona release the crs attribute of features will
#
# ...
